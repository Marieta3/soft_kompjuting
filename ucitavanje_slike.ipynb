# %% [markdown]
# <a href="https://colab.research.google.com/github/Marieta3/soft-computing-siit-2019/blob/master/ucitavanje_slike.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
# !wget -cq https://github.com/ftn-ai-lab/sc-2019-siit/blob/master/v1-uvod/images/bulbs.jpg?raw=true

# %%
img = cv.imread('girl.jpg' )
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
gray = cv.cvtColor(img, cv.COLOR_RGB2GRAY)

# %%
plt.imshow(gray, 'gray')
